# %%
"""
Experiment 1
LABELS=>
  DDoS : 1
BENIGN : 0

"""

# %%
"""
Experiment 1.1
without Feature Selection

"""

# %%
# Reading CSV file
# Library used : pandas

# %%
import pandas as pd

# %%
Attack_Benign_dataset = pd.read_csv("E:/Ankit files/IoT23_thesis/Preprocess_BinaryFiles/Attack_Benign_binary.csv")

# %%
# Labels and varraiable information in the file displayed

# %%
cnt_types =  Attack_Benign_dataset['Label'].value_counts()
print(cnt_types)
# Out:
# 1    35098
# 0    31381
# Name: Label, dtype: int64

# %%
Attack_Benign_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66479 entries, 0 to 66478
# Data columns (total 64 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Flow Duration               66479 non-null  int64
#  1   Total Fwd Packet            66479 non-null  int64
#  2   Total Bwd packets           66479 non-null  int64
#  3   Total Length of Fwd Packet  66479 non-null  int64
#  4   Total Length of Bwd Packet  66479 non-null  int64
#  5   Fwd Packet Length Max       66479 non-null  int64
#  6   Fwd Packet Length Min       66479 non-null  int64
#  7   Fwd Packet Length Mean      66479 non-null  float64
#  8   Fwd Packet Length Std       66479 non-null  float64
#  9   Bwd Packet Length Max       66479 non-null  int64
#  10  Bwd Packet Length Min       66479 non-null  int64
#  11  Bwd Packet Length Mean      66479 non-null  float64
#  12  Bwd Packet Length Std       66479 non-null  float64
#  13  Flow Bytes/s                66447 non-null  float64
#  14  Flow Packets/s              66479 non-null  float64
#  15  Flow IAT Mean               66479 non-null  float64
#  16  Flow IAT Std                66479 non-null  float64
#  17  Flow IAT Max                66479 non-null  int64
#  18  Flow IAT Min                66479 non-null  int64
#  19  Fwd IAT Total               66479 non-null  int64
#  20  Fwd IAT Mean                66479 non-null  float64
#  21  Fwd IAT Std                 66479 non-null  float64
#  22  Fwd IAT Max                 66479 non-null  int64
#  23  Fwd IAT Min                 66479 non-null  int64
#  24  Bwd IAT Total               66479 non-null  int64
#  25  Bwd IAT Mean                66479 non-null  float64
#  26  Bwd IAT Std                 66479 non-null  float64
#  27  Bwd IAT Max                 66479 non-null  int64
#  28  Bwd IAT Min                 66479 non-null  int64
#  29  Fwd Header Length           66479 non-null  int64
#  30  Bwd Header Length           66479 non-null  int64
#  31  Fwd Packets/s               66479 non-null  float64
#  32  Bwd Packets/s               66479 non-null  float64
#  33  Packet Length Min           66479 non-null  int64
#  34  Packet Length Max           66479 non-null  int64
#  35  Packet Length Mean          66479 non-null  float64
#  36  Packet Length Std           66479 non-null  float64
#  37  Packet Length Variance      66479 non-null  float64
#  38  FIN Flag Count              66479 non-null  int64
#  39  SYN Flag Count              66479 non-null  int64
#  40  RST Flag Count              66479 non-null  int64
#  41  PSH Flag Count              66479 non-null  int64
#  42  ACK Flag Count              66479 non-null  int64
#  43  URG Flag Count              66479 non-null  int64
#  44  Average Packet Size         66479 non-null  float64
#  45  Fwd Segment Size Avg        66479 non-null  float64
#  46  Bwd Segment Size Avg        66479 non-null  float64
#  47  Bwd Packet/Bulk Avg         66479 non-null  int64
#  48  Bwd Bulk Rate Avg           66479 non-null  int64
#  49  Subflow Fwd Packets         66479 non-null  int64
#  50  Subflow Fwd Bytes           66479 non-null  int64
#  51  FWD Init Win Bytes          66479 non-null  int64
#  52  Bwd Init Win Bytes          66479 non-null  int64
#  53  Fwd Act Data Pkts           66479 non-null  int64
#  54  Fwd Seg Size Min            66479 non-null  int64
#  55  Active Mean                 66479 non-null  float64
#  56  Active Std                  66479 non-null  float64
#  57  Active Max                  66479 non-null  int64
#  58  Active Min                  66479 non-null  int64
#  59  Idle Mean                   66479 non-null  float64
#  60  Idle Std                    66479 non-null  float64
#  61  Idle Max                    66479 non-null  float64
#  62  Idle Min                    66479 non-null  float64
#  63  Label                       66479 non-null  int64
# dtypes: float64(26), int64(38)
# memory usage: 32.5 MB

# %%
Attack_Benign_dataset.shape
# Out:
# (66479, 64)

# %%
# Accessing independent varriables(Features) and dependent varriables(Labels)

# %%
x = Attack_Benign_dataset.iloc[:, (Attack_Benign_dataset.columns!='Label')]
y = Attack_Benign_dataset.iloc[:,-1]

# %%
# Normalization of independent varriables

# %%
x_norm = (x-x.mean())/x.std()

# %%
# check for corelation

# %%
crr1=x_norm.corr()
crr1.isnull().sum()
# Out:
# Flow Duration                 0
# Total Fwd Packet              0
# Total Bwd packets             0
# Total Length of Fwd Packet    0
# Total Length of Bwd Packet    0
#                              ..
# Active Min                    0
# Idle Mean                     0
# Idle Std                      0
# Idle Max                      0
# Idle Min                      0
# Length: 63, dtype: int64

# %%
# check for correlation

# %%
sd1 = x_norm.std()
print(sd1[0:10])
print(sd1[10:30])
print(sd1[30:60])
print(sd1[60:70])
# Out:
# Flow Duration                 1.0
# Total Fwd Packet              1.0
# Total Bwd packets             1.0
# Total Length of Fwd Packet    1.0
# Total Length of Bwd Packet    1.0
# Fwd Packet Length Max         1.0
# Fwd Packet Length Min         1.0
# Fwd Packet Length Mean        1.0
# Fwd Packet Length Std         1.0
# Bwd Packet Length Max         1.0
# dtype: float64
# Bwd Packet Length Min     1.0
# Bwd Packet Length Mean    1.0
# Bwd Packet Length Std     1.0
# Flow Bytes/s              1.0
# Flow Packets/s            1.0
# Flow IAT Mean             1.0
# Flow IAT Std              1.0
# Flow IAT Max              1.0
# Flow IAT Min              1.0
# Fwd IAT Total             1.0
# Fwd IAT Mean              1.0
# Fwd IAT Std               1.0
# Fwd IAT Max               1.0
# Fwd IAT Min               1.0
# Bwd IAT Total             1.0
# Bwd IAT Mean              1.0
# Bwd IAT Std               1.0
# Bwd IAT Max               1.0
# Bwd IAT Min               1.0
# Fwd Header Length         1.0
# dtype: float64
# Bwd Header Length         1.0
# Fwd Packets/s             1.0
# Bwd Packets/s             1.0
# Packet Length Min         1.0
# Packet Length Max         1.0
# Packet Length Mean        1.0
# Packet Length Std         1.0
# Packet Length Variance    1.0
# FIN Flag Count            1.0
# SYN Flag Count            1.0
# RST Flag Count            1.0
# PSH Flag Count            1.0
# ACK Flag Count            1.0
# URG Flag Count            1.0
# Average Packet Size       1.0
# Fwd Segment Size Avg      1.0
# Bwd Segment Size Avg      1.0
# Bwd Packet/Bulk Avg       1.0
# Bwd Bulk Rate Avg         1.0
# Subflow Fwd Packets       1.0
# Subflow Fwd Bytes         1.0
# FWD Init Win Bytes        1.0
# Bwd Init Win Bytes        1.0
# Fwd Act Data Pkts         1.0
# Fwd Seg Size Min          1.0
# Active Mean               1.0
# Active Std                1.0
# Active Max                1.0
# Active Min                1.0
# Idle Mean                 1.0
# dtype: float64
# Idle Std    1.0
# Idle Max    1.0
# Idle Min    1.0
# dtype: float64

# %%
# applying ML Models

# %%
# Dividing in x_train , x_test , y_train and y_test

# %%
from sklearn.model_selection import train_test_split
seed = 7
test_size = 0.20
x_train, x_test, y_train, y_test = train_test_split(x_norm, y, test_size=test_size, random_state=seed)

# %%
"""
Experiment 1.1.1
LWGB

"""

# %%
from lightgbm import LGBMClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
import datetime
a = datetime.datetime.now().replace(microsecond=0)
model = LGBMClassifier()
model.fit(x_train, y_train)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(model, x_test, y_test, scoring='accuracy', cv=cv, n_jobs=-1)
# report performance
from numpy import mean
from numpy import std
print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
import sklearn.metrics as metrics
y_pred = model.predict(x_test)
print("Accuracy =", metrics.accuracy_score(y_test, y_pred))
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
b = datetime.datetime.now().replace(microsecond=0)
print(b-a)
# Out:
# Accuracy: 0.998 (0.001)
# Accuracy = 0.9990974729241877
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6382
#            1       1.00      1.00      1.00      6914
#
#     accuracy                           1.00     13296
#    macro avg       1.00      1.00      1.00     13296
# weighted avg       1.00      1.00      1.00     13296
#
# 0:00:07

# %%
"""
Experiment 1.1.2
XGBoost

"""

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
import datetime
import sklearn.metrics as metrics

first_time = datetime.datetime.now()
# fit model no training data
model = XGBClassifier()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print("Accuracy =", metrics.accuracy_score(y_test, y_pred))

cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(model, x_test, y_test, scoring='accuracy', cv=cv, n_jobs=-1)
from numpy import mean
from numpy import std
print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
later_time = datetime.datetime.now()
difference = later_time -  first_time
print(difference)
# Out:
# D:\SOFTWARES\Anaconda\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [13:24:48] WARNING: ..\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy = 0.9989470517448856
# Accuracy: 0.998 (0.001)
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6382
#            1       1.00      1.00      1.00      6914
#
#     accuracy                           1.00     13296
#    macro avg       1.00      1.00      1.00     13296
# weighted avg       1.00      1.00      1.00     13296
#
# 0:00:32.968207

# %%
"""
Experiment 1.1.3
DeepForest

"""

# %%
import numpy
x_train=x_train.values
y_train=y_train.values
x_test=x_test.values
y_test=y_test.values

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
import datetime
import sklearn.metrics as metrics


from deepforest import CascadeForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
first_time = datetime.datetime.now()
model = CascadeForestClassifier( )
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print("Accuracy =", metrics.accuracy_score(y_test, y_pred))
acc = accuracy_score(y_test,  y_pred) * 100
print("\nTesting Accuracy: {:.3f} %".format(acc))
later_time = datetime.datetime.now()
difference = later_time - first_time
print(difference)
# Out:
# [2021-11-26 20:00:44.856] Start to fit the model:
# [2021-11-26 20:00:44.856] Fitting cascade layer = 0
# [2021-11-26 20:00:54.797] layer = 0  | Val Acc = 99.883 % | Elapsed = 9.941 s
# [2021-11-26 20:00:54.838] Fitting cascade layer = 1
# [2021-11-26 20:01:04.506] layer = 1  | Val Acc = 99.885 % | Elapsed = 9.668 s
# [2021-11-26 20:01:04.540] Fitting cascade layer = 2
# [2021-11-26 20:01:14.673] layer = 2  | Val Acc = 99.878 % | Elapsed = 10.132 s
# [2021-11-26 20:01:14.673] Early stopping counter: 1 out of 2
# [2021-11-26 20:01:14.755] Fitting cascade layer = 3
# [2021-11-26 20:01:23.160] layer = 3  | Val Acc = 99.883 % | Elapsed = 8.405 s
# [2021-11-26 20:01:23.161] Early stopping counter: 2 out of 2
# [2021-11-26 20:01:23.161] Handling early stopping
# [2021-11-26 20:01:23.162] The optimal number of layers: 2
# [2021-11-26 20:01:23.164] Start to evalute the model:
# [2021-11-26 20:01:23.183] Evaluating cascade layer = 0
# [2021-11-26 20:01:23.501] Evaluating cascade layer = 1
# Accuracy = 0.9983453670276775
#
# Testing Accuracy: 99.835 %
# 0:00:39.120867

# %%
c_r = classification_report(y_test, y_pred)
c_m = confusion_matrix(y_test, y_pred)
print(c_r)
print(c_m)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6382
#            1       1.00      1.00      1.00      6914
#
#     accuracy                           1.00     13296
#    macro avg       1.00      1.00      1.00     13296
# weighted avg       1.00      1.00      1.00     13296
#
# [[6371   11]
#  [  10 6904]]

# %%
# Heat Maps

# %%
import matplotlib.pyplot as plt
import seaborn as sns
corrmat = x_norm.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(x_norm[top_corr_features].corr(),annot=False,cmap="RdYlGn")
